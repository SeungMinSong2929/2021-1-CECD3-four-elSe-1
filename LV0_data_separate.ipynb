# %% [markdown]
# <a href="https://colab.research.google.com/github/SeungMinSong2929/2021-1-CECD3-four-elSe-1/blob/master/product_image_processing0323.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LV0 단위로 csv 파일 분리
#
# * LV0_데이터이름 의 파일 디렉토리 생성
# * 생성된 디렉토리 내에 LV0 csv 파일 생성

# %%
#드라이브에 접근할 수 있도록 아래 코드 입력
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 데이터 불러오기

# %% [markdown]
# #### 본인 파일 경로를 기본 경로로 저장

# %%
# 원본 데이터가 있는 기본 경로 저장.
filePath = "/content/drive/My Drive/forElse"

# %%
import pandas as pd

# hanssem_product_images.UTF-8.csv
origin_data = pd.read_csv(filePath+"/hanssem_product_images_UTF8.csv")
origin_data.head()
# Out:
#    PROD_ID  ...                                            IMG_URL
# 0   578214  ...  https://image.hanssem.com/hsimg//gds/550/578/5...
# 1   578215  ...  https://image.hanssem.com/hsimg//gds/550/578/5...
# 2   543542  ...  https://image.hanssem.com/hsimg//gds/550/543/5...
# 3   543535  ...  https://image.hanssem.com/hsimg//gds/550/543/5...
# 4   543529  ...  https://image.hanssem.com/hsimg//gds/550/543/5...
#
# [5 rows x 6 columns]

# %% [markdown]
# ## 데이터 구성 파악하기

# %%
LV0_data= list(set(origin_data['LV0']))
LV1_data= list(set(origin_data['LV1']))
LV2_data= list(set(origin_data['LV2']))
print("LV0_data\t 총 ", len(LV0_data), "개", LV0_data)
print("=========="*3)
print("LV1_data\t 총 ", len(LV1_data), "개", LV1_data)
print("=========="*3)
print("LV2_data\t 총 ", len(LV2_data), "개", LV2_data)
print("=========="*3)
# Out:
# LV0_data	 총  9 개 ['침대/침실가구', '옷장/붙박이장', '침구/커튼/러그', '식탁/주방가구', '유아동가구/용품', '인테리어소가구', '책장/책상/의자', '소파/거실가구', '조명']
# ==============================
# LV1_data	 총  27 개 ['블라인드', '바체어', '테이블', '매트리스', '거실장', '주방수납', '거실테이블', '유아매트', '포인트조명', '스탠드조명', '수납', '의자', '러그', '소파', '식탁의자', '커튼', '테이블조명', '수납장', '방조명', '식탁', '책장', '침대', '침구', '드레스룸', '책상', '옷장', '붙박이장']
# ==============================
# LV2_data	 총  294 개 ['안락/중역용 의자', '수유등/무드등', '너비 60cm 이하', '수납 액세서리', '협탁', '하이그로시', '철제형 드레스룸', '너비_ 130cm 이상', '기타/조명ACC', '커튼(러블리/플라워)', 'PVC매트/요가매트/여름자리', '커튼(린넨)', '기능성 책상', '빈티지(유리/스틸)', '소파 패키지 초특가', '커튼(레이스/쉬폰/속커튼)', '스툴', '침구단품', '확장형', '4~6단', '토퍼', '아동 의자', '스틸드레스룸(깊이40cm)', '├ 아임빅 슬라이딩 옷장', 'S/SS(도트/패턴)', '1~3단 서랍장/협탁', '일자형', '이불커버', '4인', '암막커튼(러블리/플라워)', '주방조명', '기능성 의자', '커튼(키즈/캐릭터)', '베개', '알러지 기능성 카페트', '행거', '무헤드/기본 침대', '우드', '철제수납장', '여닫이 붙박이장', '행거/선반형', '원목 침대', '스틸 침대', '서랍/수납형', '높이_ 1~3단', '클램프/집게형 조명', '옷장 세트', '천연가죽소파', '5인 이상', '좌식 책상', '매트리스커버', '콤비 블라인드', '패드/스프레드', '각도조절책상', '가로 40~60cm', '책장/신발장', '시스템거실장', 'LED스탠드 ', '
플라워)', '독서실 책상', '책장', '허니콤 블라인드', '패브릭 침대', '패브릭매트', '침구세트', '한샘수납장', '4인용', '송치카페트', 'Q/D/K(차렵)', '패브릭', '테이블/플로어 세트 PKG', 'Q+SS 침대', '수납_ 전면 책상', '프린팅 러그(DTP)', '침대 액세서리', '벽등/포인트등', '킹침대 모아보기', '너비_60cm이상~1m미만', '패브릭소파', '램프등/샹들리에', '텐트/놀이집', 'Q/D/K(러블리/플라워)', '목대드레스룸(깊이60cm)', 'S/SS(광목/린넨 내츄럴)', '주니어장(높은옷장)', '이층/벙커 침대', '리프트업 테이블', '일반책장', '더블침대 모아보기', '사이드 테이블', '돌/흙침대보료', 'Q/D/K(호텔/럭셔리)', '암막커튼(북유럽/프린팅)', '로만쉐이드', '합성가죽', '범퍼침대', '책장 수납액세서리', 'Q+Q 침대', '틈새수납장', '2인', '바테이블', '가로 40~50cm', 'Q/D/K(체크/스트라이프)', '학습 의자', '신발장', '유리/대리석 테이블', '가로 100cm 이상', '커튼(무지/솔리드)', 'Q/D/K(도트/패턴)', '베개/베캐커버', '일반등', '한샘책장', '선반장/장식장', '합성가죽소파', 'Q/D/K(무지/솔리드)', '스툴/소파ACC', '너비_90cm미만', '┌ 피카 키큰옷장', '소파', '요/요커버', '베개커버(무지/솔리드)', '폴더매트', 'Q/D/K(광목/린넨 내츄럴)', '트리플 블라인드', '화장대', '이동서랍장', '거실조명', '천연가죽', 'Q/SS 단독형침대', '전면책장', '원목/무늬목 테이블', 'Q/D/K(캐릭터/일러스트)', 'S/SS(홑이불)', '1인용', '높은거실장/수납장', '기저귀수납', '빈백', '원형러그', '암막커튼(무지/솔리드)', '베개커버(프린팅/일러스트)', '라텍스/메모리폼 매트', '컴퓨터 책상', '와이드 서랍장', '발매트', '네추럴(우드)', '├ 바이엘 슬라이딩 옷장', '베이직러그(솔리드)']
# ==============================

# %% [markdown]
# ## 데이터 정보를 저장할 새로운 경로 생성
#
# 파일 이름: csv

# %%
import os

csvPath = filePath+"/csv"
if not os.path.isdir(csvPath):
  os.mkdir(csvPath)

# %% [markdown]
# # LV0별로 csv 파일 생성

# %%
# LV0별로 새로운 디렉토리에 csv 파일 생성.
# 데이터명 변경 '/' -> '+'
import re
LV0_plus=[]
for i in LV0_data:
  # LV0_data 변경
  level0 = i
  #print(level0)
  this_LV0_df = origin_data[origin_data['LV0'] == i]
  print(this_LV0_df.head())
  slash_loc =[]
  for a in re.finditer('/', level0):
    slash_loc.append(a.start())
  #print(slash_loc)
  if len(slash_loc)==1:
    level0 = i[0:slash_loc[0]]+'+'+i[slash_loc[0]+1:]
  if len(slash_loc)==2:
    level0 = i[0:slash_loc[0]]+'+'+i[slash_loc[0]+1:slash_loc[1]]+'+'+i[slash_loc[1]+1:]
  #print(i, level0)
  LV0_plus.append(level0)
  
  
  # 데이터프레임의 LV0값 변경
  this_LV0_df['LV0'] = level0
  print(this_LV0_df['LV0'])

  LV0Path = csvPath+'/LV0_'+level0
  if not os.path.isdir(LV0Path):
    os.mkdir(LV0Path)

  csvFileName = LV0Path+'/LV0_'+level0+'.csv'
  print(csvFileName)
  this_LV0_df.to_csv(csvFileName, encoding ='utf-8-sig', index = False)

print(LV0_data)
print(LV0_plus)
LV0_data = LV0_plus[:]
# Out:
#    PROD_ID  ...                                            IMG_URL
# 0   578214  ...  https://image.hanssem.com/hsimg//gds/550/578/5...
# 1   578215  ...  https://image.hanssem.com/hsimg//gds/550/578/5...
# 2   543542  ...  https://image.hanssem.com/hsimg//gds/550/543/5...
# 3   543535  ...  https://image.hanssem.com/hsimg//gds/550/543/5...
# 4   543529  ...  https://image.hanssem.com/hsimg//gds/550/543/5...
#
# [5 rows x 6 columns]
# 0        침대+침실가구
# 1        침대+침실가구
# 2        침대+침실가구
# 3        침대+침실가구
# 4        침대+침실가구
#           ...
# 67042    침대+침실가구
# 67043    침대+침실가구
# 67044    침대+침실가구
# 67045    침대+침실가구
# 67046    침대+침실가구
# Name: LV0, Length: 13048, dtype: object
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /content/drive/My Drive/forElse/csv/LV0_침대+침실가구/LV0_침대+침실가구.csv
#        PROD_ID  ...                                            IMG_URL
# 21668    39556  ...  https://image.hanssem.com/hsimg//gds/550/39/39...
# 21669    39557  ...  https://image.hanssem.com/hsimg//gds/550/39/39...
# 21670    39559  ...  https://image.hanssem.com/hsimg//gds/550/39/39...
# 21671    39560  ...  https://image.hanssem.com/hsimg//gds/550/39/39...
# 21672    39563  ...  https://image.hanssem.com/hsimg//gds/550/39/39...
#
# [5 rows x 6 columns]
# 21668    옷장+붙박이장
# 21669    옷장+붙박이장
# 21670    옷장+붙박이장
# 21671    옷장+붙박이장
# 21672    옷장+붙박이장
#           ...
# 25825    옷장+붙박이장
# 25826    옷장+붙박이장
# 25827    옷장+붙박이장
# 25828    옷장+붙박이장
# 25829    옷장+붙박이장
# Name: LV0, Length: 4162, dtype: object
# /content/drive/My Drive/forElse/csv/LV0_옷장+붙박이장/LV0_옷장+붙박이장.csv
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       PROD_ID  ...                                            IMG_URL
# 4594   366952  ...  https://image.hanssem.com/hsimg//gds/550/366/3...
# 4595   366953  ...  https://image.hanssem.com/hsimg//gds/550/366/3...
# 4596   367046  ...  https://image.hanssem.com/hsimg//gds/550/367/3...
# 4597   366984  ...  https://image.hanssem.com/hsimg//gds/550/366/3...
# 4598   366985  ...  https://image.hanssem.com/hsimg//gds/550/366/3...
#
# [5 rows x 6 columns]
# 4594     침구+커튼+러그
# 4595     침구+커튼+러그
# 4596     침구+커튼+러그
# 4597     침구+커튼+러그
# 4598     침구+커튼+러그
#            ...
# 58588    침구+커튼+러그
# 58589    침구+커튼+러그
# 58590    침구+커튼+러그
# 58591    침구+커튼+러그
# 58592    침구+커튼+러그
# Name: LV0, Length: 23875, dtype: object
# /content/drive/My Drive/forElse/csv/LV0_침구+커튼+러그/LV0_침구+커튼+러그.csv
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        PROD_ID  ...                                            IMG_URL
# 25830    69156  ...  https://image.hanssem.com/hsimg//gds/550/69/69...
# 25831    73706  ...  https://image.hanssem.com/hsimg//gds/550/73/73...
# 25832    75462  ...  https://image.hanssem.com/hsimg//gds/550/75/75...
# 25833    78581  ...  https://image.hanssem.com/hsimg//gds/550/78/78...
# 25834    80815  ...  https://image.hanssem.com/hsimg//gds/550/80/80...
#
# [5 rows x 6 columns]
# 25830    식탁+주방가구
# 25831    식탁+주방가구
# 25832    식탁+주방가구
# 25833    식탁+주방가구
# 25834    식탁+주방가구
#           ...
# 31470    식탁+주방가구
# 31471    식탁+주방가구
# 31472    식탁+주방가구
# 31473    식탁+주방가구
# 31474    식탁+주방가구
# Name: LV0, Length: 5645, dtype: object
# /content/drive/My Drive/forElse/csv/LV0_식탁+주방가구/LV0_식탁+주방가구.csv
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        PROD_ID  ...                                            IMG_URL
# 21015    25613  ...  https://image.hanssem.com/hsimg//gds/550/25/25...
# 21016    44231  ...  https://image.hanssem.com/hsimg//gds/550/44/44...
# 21017    44232  ...  https://image.hanssem.com/hsimg//gds/550/44/44...
# 21018    44233  ...  https://image.hanssem.com/hsimg//gds/550/44/44...
# 21019    86933  ...  https://image.hanssem.com/hsimg//gds/550/86/86...
#
# [5 rows x 6 columns]
# 21015    유아동가구+용품
# 21016    유아동가구+용품
# 21017    유아동가구+용품
# 21018    유아동가구+용품
# 21019    유아동가구+용품
#            ...
# 21663    유아동가구+용품
# 21664    유아동가구+용품
# 21665    유아동가구+용품
# 21666    유아동가구+용품
# 21667    유아동가구+용품
# Name: LV0, Length: 653, dtype: object
# /content/drive/My Drive/forElse/csv/LV0_유아동가구+용품/LV0_유아동가구+용품.csv
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        PROD_ID  ...                                            IMG_URL
# 11354    67077  ...  https://image.hanssem.com/hsimg//gds/550/67/67...
# 11355    68283  ...  https://image.hanssem.com/hsimg//gds/550/68/68...
# 11356    68286  ...  https://image.hanssem.com/hsimg//gds/550/68/68...
# 11357    68294  ...  https://image.hanssem.com/hsimg//gds/550/68/68...
# 11358    68295  ...  https://image.hanssem.com/hsimg//gds/550/68/68...
#
# [5 rows x 6 columns]
# 11354    인테리어소가구
# 11355    인테리어소가구
# 11356    인테리어소가구
# 11357    인테리어소가구
# 11358    인테리어소가구
#           ...
# 21010    인테리어소가구
# 21011    인테리어소가구
# 21012    인테리어소가구
# 21013    인테리어소가구
# 21014    인테리어소가구
# Name: LV0, Length: 9661, dtype: object
# /content/drive/My Drive/forElse/csv/LV0_인테리어소가구/LV0_인테리어소가구.csv
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       PROD_ID  ...                                            IMG_URL
# 5322    37957  ...  https://image.hanssem.com/hsimg//gds/550/37/37...
# 5323    37959  ...  https://image.hanssem.com/hsimg//gds/550/37/37...
# 5324    37960  ...  https://image.hanssem.com/hsimg//gds/550/37/37...
# 5325    37961  ...  https://image.hanssem.com/hsimg//gds/550/37/37...
# 5326    37962  ...  https://image.hanssem.com/hsimg//gds/550/37/37...
#
# [5 rows x 6 columns]
# 5322    책장+책상+의자
# 5323    책장+책상+의자
# 5324    책장+책상+의자
# 5325    책장+책상+의자
# 5326    책장+책상+의자
#           ...
# 7914    책장+책상+의자
# 7915    책장+책상+의자
# 7916    책장+책상+의자
# 7917    책장+책상+의자
# 7918    책장+책상+의자
# Name: LV0, Length: 2597, dtype: object
# /content/drive/My Drive/forElse/csv/LV0_책장+책상+의자/LV0_책장+책상+의자.csv
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        PROD_ID  ...                                            IMG_URL
# 31475    69103  ...  https://image.hanssem.com/hsimg//gds/550/69/69...
# 31476    69104  ...  https://image.hanssem.com/hsimg//gds/550/69/69...
# 31477    69105  ...  https://image.hanssem.com/hsimg//gds/550/69/69...
# 31478    69106  ...  https://image.hanssem.com/hsimg//gds/550/69/69...
# 31479    69128  ...  https://image.hanssem.com/hsimg//gds/550/69/69...
#
# [5 rows x 6 columns]
# 31475    소파+거실가구
# 31476    소파+거실가구
# 31477    소파+거실가구
# 31478    소파+거실가구
# 31479    소파+거실가구
#           ...
# 35441    소파+거실가구
# 35442    소파+거실가구
# 35443    소파+거실가구
# 35444    소파+거실가구
# 35445    소파+거실가구
# Name: LV0, Length: 3971, dtype: object
# /content/drive/My Drive/forElse/csv/LV0_소파+거실가구/LV0_소파+거실가구.csv
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       PROD_ID  ...                                            IMG_URL
# 7919    20134  ...  https://image.hanssem.com/hsimg//gds/550/20/20...
# 7920    20135  ...  https://image.hanssem.com/hsimg//gds/550/20/20...
# 7921    20137  ...  https://image.hanssem.com/hsimg//gds/550/20/20...
# 7922    20138  ...  https://image.hanssem.com/hsimg//gds/550/20/20...
# 7923    20140  ...  https://image.hanssem.com/hsimg//gds/550/20/20...
#
# [5 rows x 6 columns]
# 7919     조명
# 7920     조명
# 7921     조명
# 7922     조명
# 7923     조명
#          ..
# 11349    조명
# 11350    조명
# 11351    조명
# 11352    조명
# 11353    조명
# Name: LV0, Length: 3435, dtype: object
# /content/drive/My Drive/forElse/csv/LV0_조명/LV0_조명.csv
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ['침대/침실가구', '옷장/붙박이장', '침구/커튼/러그', '식탁/주방가구', '유아동가구/용품', '인테리어소가구', '책장/책상/의자', '소파/거실가구', '조명']
# ['침대+침실가구', '옷장+붙박이장', '침구+커튼+러그', '식탁+주방가구', '유아동가구+용품', '인테리어소가구', '책장+책상+의자', '소파+거실가구', '조명']
