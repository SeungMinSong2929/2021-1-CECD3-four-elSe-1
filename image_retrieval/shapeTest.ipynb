# %%
import os
from src.CV_transform_utils import apply_transformer
from src.CV_transform_utils import resize_img, normalize_img
from glob import glob

# %%
train_paths = glob("./data/train/*.jpg")
len(train_paths)
# Out:
# 2680

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
image_pil = Image.open(train_paths[0])
plt.imshow(image_pil)

# %%
# Out:
# (512, 512, 3)

# %%
image_resized = image_pil.resize((512,512))
plt.imshow(image_resized)

# %%
from tqdm import tqdm
lion_image = Image.open("./0.jpg")
lion_image = np.array(lion_image)
print(lion_image.shape)
plt.imshow(lion_image)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-2b37c790cb21> in <module>
# ----> 1 from tqdm import tqdm
#       2 lion_image = Image.open("./0.jpg")
#       3 lion_image = np.array(lion_image)
#       4 print(lion_image.shape)
#       5 plt.imshow(lion_image)
#
# ModuleNotFoundError: No module named 'tqdm'

# %%
for path in train_paths:
    image_pil = Image.open(path)
    image_resized = image_pil.resize((512,512))
    image_resized.save(path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-8c90e62e8321> in <module>
#       1 for path in train_paths:
#       2     image_pil = Image.open(path)
# ----> 3     image_resized = image_pil.resize((512,512))
#       4     image_resized.save(path)
#
# C:\ProgramData\Anaconda3\envs\tf1.15\lib\site-packages\PIL\Image.py in resize(self, size, resample, box, reducing_gap)
#    1908             return im.convert(self.mode)
#    1909
# -> 1910         self.load()
#    1911
#    1912         if reducing_gap is not None and resample != NEAREST:
#
# C:\ProgramData\Anaconda3\envs\tf1.15\lib\site-packages\PIL\ImageFile.py in load(self)
#     259
#     260                             b = b + s
# --> 261                             n, err_code = decoder.decode(b)
#     262                             if n < 0:
#     263                                 break
#
# ...
