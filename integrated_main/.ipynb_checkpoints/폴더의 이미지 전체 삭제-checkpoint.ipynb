# %%
from glob import glob
images = glob("./retrieval_data/train/*.jpg")
images
# Out:
# ['./retrieval_data/train/pizza17_path: (.-person_data-person000526.png).jpg',
#  './retrieval_data/train/cup74_path: (.-person_data-person000196.png).jpg',
#  './retrieval_data/train/person1457_path: (.-person_data-person000258.png).jpg',
#  './retrieval_data/train/tie33_path: (.-person_data-person000318.png).jpg',
#  './retrieval_data/train/person1692_path: (.-person_data-person000537.png).jpg',
#  './retrieval_data/train/person1473_path: (.-person_data-person000558.png).jpg',
#  './retrieval_data/train/person1219_path: (.-person_data-person000476.png).jpg',
#  './retrieval_data/train/wine glass15_path: (.-person_data-person000125.png).jpg',
#  './retrieval_data/train/person1410_path: (.-person_data-person000987.png).jpg',
#  './retrieval_data/train/elephant4_path: (.-person_data-person000498.png).jpg',
#  './retrieval_data/train/person1381_path: (.-person_data-person000940.png).jpg',
#  './retrieval_data/train/chair97_path: (.-person_data-person001018.png).jpg',
# ...

# %%
import os
for image in images:
    os.remove(image)

# %%
os.listdir("./retrieval_data/train")
# Out:
# []
