# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("CroppedImage.txt", "rb") as f:
    croppedImages = pickle.load(f)

# %%
len(croppedImages)
# Out:
# 1

# %%
plt.imshow(croppedImages[0][0])

# %%
# len(croppedImage) == 3000 이어야함함
